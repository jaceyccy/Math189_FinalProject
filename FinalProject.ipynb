# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Central Question: Given placed status, can student salary packages be predicted from academic, technical, and professional features?

# %%
df = pd.read_csv('raw_data.csv')
df.head(5)
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    mock_interview_score  attendance_percentage  backlogs  \
# 0             72.647009              77.463863         2
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (100000, 26)

# %%
df.isna().sum().sum()
# The dataset contain no missing values
# Out:
# np.int64(0)

# %%
df['salary_package_lpa'].describe()
# Out:
# count    100000.000000
# mean          7.252106
# std           6.735132
# min           0.000000
# 25%           0.000000
# 50%          11.100000
# 75%          13.470000
# max          20.440000
# Name: salary_package_lpa, dtype: float64

# %%
px.histogram(df, x = 'salary_package_lpa')

# %%
df['placement_status'].value_counts(normalize=True)
# Out:
# placement_status
# Placed        0.54459
# Not Placed    0.45541
# Name: proportion, dtype: float64

# %%
placed_df = df[df['placement_status'] == 'Placed']
placed_df
# Out:
#        student_id  age  gender  cgpa      branch college_tier  \
# 2               3   22  Female  8.60         EEE       Tier 1
# 4               5   20  Female  8.43          IT       Tier 3
# 5               6   22    Male  7.44         CSE       Tier 2
# 8               9   19    Male  8.52  Mechanical       Tier 2
# 9              10   20  Female  8.07       Civil       Tier 2
# ...           ...  ...     ...   ...         ...          ...
# 99989       99990   20    Male  7.75         CSE       Tier 2
# 99991       99992   23  Female  8.10       Civil       Tier 2
# 99995       99996   21    Male  7.97  Mechanical       Tier 2
# 99997       99998   20  Female  6.71          IT       Tier 2
# 99999      100000   22  Female  8.58         ECE       Tier 3
#
#        internships_count  projects_count  certifications_count  \
# 2                      0               1                     1
# 4                      1               4                     3
# ...

# %% [markdown]
# ## Analysis, Hypothesis Testing

# %% [markdown]
# ## Modeling
